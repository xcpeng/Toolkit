# %%
filepath = '/Users/xidexia/Desktop/BU/Research/xingchao/CVPR2019_DA/plots/reda_categories_hierarchicalinvitationtoedit/'

filename = filepath + 'clipart_N_sample.txt'
with open(filename) as f:
    clipart_N_sample = f.readlines()
    
filename = filepath + 'infograph_N_sample.txt'
with open(filename) as f:
    infograph_N_sample = f.readlines()
    
filename = filepath + 'painting_N_sample.txt'
with open(filename) as f:
    painting_N_sample = f.readlines()
    
filename = filepath + 'quickdraw_N_sample.txt'
with open(filename) as f:
    quickdraw_N_sample = f.readlines()
    
filename = filepath + 'real_N_sample.txt'
with open(filename) as f:
    real_N_sample = f.readlines()
    
filename = filepath + 'sketch_N_sample.txt'
with open(filename) as f:
    sketch_N_sample = f.readlines()

# %%
i=0
all_ct_dict = {}
clipart_ct_dict = {}
infograph_ct_dict = {}
painting_ct_dict = {}
quickdraw_ct_dict = {}
real_ct_dict = {}
sketch_ct_dict = {}

for i in xrange(len(sketch_N_sample)):
    
    curr_txt = clipart_N_sample
    key = curr_txt[i][:curr_txt[i][:-1].find(':')] 
    if key == 'The_Great_Wall_of_China': key = 'The_Great_Wall'
    key = key.replace('_',' ')    
    ct = int(curr_txt[i][curr_txt[i][:-1].find(':')+1:-1] )
    all_ct_dict[key] = [ct]
    clipart_ct_dict[key] = ct
    
    curr_txt = infograph_N_sample
    key = curr_txt[i][:curr_txt[i][:-1].find(':')] 
    if key == 'The_Great_Wall_of_China': key = 'The_Great_Wall'
    key = key.replace('_',' ')   
    ct = int(curr_txt[i][curr_txt[i][:-1].find(':')+1:-1] )
    all_ct_dict[key] += [ct]
    infograph_ct_dict[key] = ct
    
    curr_txt = painting_N_sample
    key = curr_txt[i][:curr_txt[i][:-1].find(':')] 
    if key == 'The_Great_Wall_of_China': key = 'The_Great_Wall'
    key = key.replace('_',' ')   
    ct = int(curr_txt[i][curr_txt[i][:-1].find(':')+1:-1] )
    all_ct_dict[key] += [ct]
    painting_ct_dict[key] = ct
    
    curr_txt = quickdraw_N_sample
    key = curr_txt[i][:curr_txt[i][:-1].find(':')] 
    if key == 'The_Great_Wall_of_China': key = 'The_Great_Wall'
    key = key.replace('_',' ')   
    ct = int(curr_txt[i][curr_txt[i][:-1].find(':')+1:-1] )
    all_ct_dict[key] += [ct]
    quickdraw_ct_dict[key] = ct
    
    curr_txt = real_N_sample
    key = curr_txt[i][:curr_txt[i][:-1].find(':')] 
    if key == 'The_Great_Wall_of_China': key = 'The_Great_Wall'
    key = key.replace('_',' ')   
    ct = int(curr_txt[i][curr_txt[i][:-1].find(':')+1:-1] )
    all_ct_dict[key] += [ct]
    real_ct_dict[key] = ct
    
    curr_txt = sketch_N_sample
    key = curr_txt[i][:curr_txt[i][:-1].find(':')] 
    if key == 'The_Great_Wall_of_China': key = 'The_Great_Wall'
    key = key.replace('_',' ')   
    ct = int(curr_txt[i][curr_txt[i][:-1].find(':')+1:-1] )
    all_ct_dict[key] += [ct]
    sketch_ct_dict[key] = ct

# %%
all_ct_dict
# Out:
# {'The Eiffel Tower': [114, 190, 321, 500, 553, 276],
#  'The Great Wall': [116, 80, 159, 500, 530, 148],
#  'The Mona Lisa': [150, 112, 191, 500, 289, 145],
#  'aircraft carrier': [27, 88, 133, 500, 390, 63],
#  'airplane': [73, 62, 212, 500, 218, 331],
#  'alarm clock': [93, 23, 84, 500, 521, 202],
#  'ambulance': [80, 20, 74, 500, 623, 115],
#  'angel': [165, 17, 504, 500, 31, 299],
#  'animal migration': [235, 68, 604, 500, 444, 112],
#  'ant': [81, 62, 235, 500, 381, 111],
#  'anvil': [122, 23, 152, 500, 332, 91],
#  'apple': [88, 75, 445, 500, 54, 181],
#  'arm': [50, 129, 422, 500, 235, 249],
#  'asparagus': [49, 134, 408, 500, 659, 209],
#  'axe': [48, 92, 219, 500, 382, 219],
#  'backpack': [33, 341, 265, 500, 439, 220],
#  'banana': [50, 376, 359, 500, 258, 204],
#  'bandage': [47, 322, 197, 500, 399, 56],
#  'barn': [157, 150, 426, 500, 313, 201],
#  'baseball': [116, 369, 122, 500, 87, 48],
#  'baseball bat': [106, 353, 145, 500, 118, 196],
# ...

# %%
sum_dict = {}
for key in all_ct_dict:
    curr_sum = sum(all_ct_dict[key])
    if not curr_sum in sum_dict:
        sum_dict[curr_sum] = [key]
    else:
        sum_dict[curr_sum].append(key)

# %%
sorted_class = []
sorted_sum = sorted(sum_dict.keys())[::-1]
new_sorted_sum = []
for k in sorted_sum:
    sorted_class += sum_dict[k]
    for i in xrange(len(sum_dict[k])):
        new_sorted_sum.append(k)

# %%
sorted_sum = new_sorted_sum

# %%
len(sorted_sum)
# Out:
# 345

# %%
import numpy as np
import matplotlib.pyplot as plt


ind = np.arange(len(sorted_class))    # the x locations for the groups
width = 0.8      # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(100,15))
#plt.figure()

plt.bar(ind, sorted_sum, width, alpha=0.7,edgecolor='black',linewidth=0.3)


plt.ylabel('Number of Instances', size=80)
plt.xticks(ind, sorted_class, size=20,  rotation=90 )
ax.set_xlim([0, len(sorted_sum)-1])
plt.yticks(np.arange(0, 3000, 1000), size=80)
plt.grid(axis = 'y', linestyle='--', linewidth = 10)
plt.show()
fig.savefig("Number of Instances.pdf", bbox_inches='tight')

# %%
group_dict = {}
group_dict['water transportation'] = ['aircraft carrier','canoe','cruise ship','sailboat','speedboat','submarine']
group_dict['road transportation'] = ['ambulance','bicycle','bulldozer','bus','car','firetruck','motorbike','pickup truck','police car','roller coaster','school bus','tractor','train','truck','van']
group_dict['sky transportation'] = ['airplane','helicopter','hot air balloon','parachute']
group_dict['furniture'] = ['see saw','bathtub','bed','bench','ceiling fan','chair','chandelier','couch','door','dresser','fence','fireplace','floor lamp','hot tub','ladder','lantern','mailbox','picture frame','pillow','postcard','sink','sleeping bag','stairs','stove','streetlight','suitcase','swing set','table','teapot','toilet','toothbrush','toothpaste','umbrella','vase','wine glass']
group_dict['tool'] = ['anvil','axe','basket','bucket','bandage','boomerang','bottlecap','broom','compass','drill','dumbbell','hammer','key','nail','paint can','passport','pliers','rake','rifle','saw','screwdriver','shovel','skateboard','stethoscope','stitches','sword','syringe','wheel']
group_dict['office'] = ['alarm clock','backpack','book','binoculars','calendar','candle','clock','coffee cup','crayon','cup','envelope','eraser','map','marker','mug','paintbrush','paper clip','pencil','scissors']
group_dict['kitchen'] = ['fork','frying pan','hourglass','knife','lighter','matches','spoon','wine bottle']
group_dict['electricity'] = ['calculator','camera','cell phone','computer','cooler','dishwasher','fan','flashlight','headphones','keyboard','laptop','light bulb','megaphone','microphone','microwave','oven','power outlet','radio','remote control','spreadsheet','stereo','telephone','television','toaster','washing machine']
group_dict['cloth'] = ['belt','bowtie','bracelet','camouflage','crown','diamond','eyeglasses','flip flops','hat','helmet','jacket','lipstick','necklace','pants','purse','rollerskates','shoe','shorts','sock','sweater','t-shirt','underwear','wristwatch']
group_dict['mammal'] = ['bat','bear','camel','cat','cow','panda','dog','dolphin','elephant','giraffe','hedgehog','horse','kangaroo','lion','monkey','mouse','pig','rabbit','raccoon','rhinoceros','sheep','squirrel','tiger','whale','zebra']
group_dict['bird'] = ['bird','duck','flamingo','owl','parrot','penguin','swan']
group_dict['cold blooded'] = ['crab','fish','frog','crocodile','octopus','scorpion','sea turtle','shark','snake','lobster','snail','spider']
group_dict['insect'] = ['ant','bee','butterfly','mosquito']
group_dict['human body'] = ['arm','beard','brain','ear','elbow','eye','face','finger','foot','goatee','hand','knee','leg','moustache','mouth','nose','skull','smiley face','toe','tooth']
group_dict['fruit'] = ['apple','banana','blackberry','blueberry','grapes','pear','pineapple','strawberry','watermelon']
group_dict['food'] = ['birthday cake','bread','cake','cookie','donut','hamburger','hot dog','ice cream','lollipop','peanut','pizza','popsicle','sandwich','steak']
group_dict['vegetable'] = ['asparagus','broccoli','carrot','mushroom','onion','peas','potato','string bean']
group_dict['tree'] = ['bush','cactus','flower','grass','house plant','leaf','palm tree','tree']
group_dict['building'] = ['barn','bridge','castle','church','diving board','garden','garden hose','golf club','hospital','house','jail','lighthouse','pond','pool','skyscraper','square','tent','The Eiffel Tower','The Great Wall','waterslide','windmill']
group_dict['nature'] = ['beach','hurricane','lightning','moon','mountain','ocean','rain','rainbow','river','snowflake','star','sun','tornado','cloud']
group_dict['sport'] = ['baseball','baseball bat','basketball','hockey puck','hockey stick','snorkel','soccer ball','tennis racquet','yoga','flying saucer']
group_dict['music'] = ['cello','clarinet','drums','guitar','harp','piano','saxophone','trombone','trumpet','violin']
group_dict['shape'] = ['circle','hexagon','line','octagon','squiggle','triangle','zigzag']
group_dict['other'] = ['animal migration','campfire','feather','fire hydrant','angel','snowman','teddy-bear','The Mona Lisa','traffic light','cannon','stop sign','dragon','mermaid']

# %%
flat_list = [item for sublist in group_dict.values() for item in sublist]
a,b = np.unique(flat_list,return_counts= True)
for i in xrange(len(b)):
    if b[i]>1: print(a[i],b[i])

# %%
group_ct_dict = {}
for curr_group in group_dict:
    group_ct_dict[curr_group] = []
    for k in group_dict[curr_group]:
        group_ct_dict[curr_group].append(sum(all_ct_dict[k]))
        
group_sum_dict = {}
for curr_group in group_dict:
    group_sum_dict[curr_group] = sum(group_ct_dict[curr_group])
    
    
    
sum_group_dict  = {group_sum_dict[k]:k for k in group_sum_dict}

sorted_group = []
sorted_group_sum = sorted(sum_group_dict.keys())[::-1]
for k in sorted_group_sum:
    sorted_group.append(sum_group_dict[k])
    
values_list = []
class_list = []
group_list = []
color_list = []
colors = ['purple','green','yellow','blue','red','pink']

j=0
temp_i = 0
temp_j = 0
for group in sorted_group: 
    tmp_dict = {}
    i= 0 
    for k in group_ct_dict[group]:
        if not k in tmp_dict:
            tmp_dict[k] = [group_dict[group][i]]
        else:
            tmp_dict[k] += [group_dict[group][i]]
        i += 1
    for k in sorted(tmp_dict.keys())[::-1]:
        for iii in xrange(len(tmp_dict[k])):
            values_list.append(k)
            class_list.append(tmp_dict[k][iii])
            group_list.append(group)
            color_list.append(colors[j%6])


    j+=1
    temp_j += i
    #if not temp_i ==temp_j: 
        #print(group)
        #print(tmp_dict.values())
        #print(group_dict[group])
        #print("    ")

# %%
i = 0
for k in group_ct_dict:
    i += len(group_ct_dict[k])
    
j=0
for i in sorted_group:
    j += len(group_ct_dict[i])
j
# Out:
# 345

# %%
len(class_list)
# Out:
# 345

# %%
import numpy as np
import matplotlib.pyplot as plt


ind = np.arange(len(class_list))    # the x locations for the groups
width = 0.9      # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(100,15))
#plt.figure()

#barlist=plt.bar(ind, values_list, width, alpha=0.7,edgecolor='black',linewidth=0.3)
barlist=plt.bar(ind, values_list, width, alpha=0.6)

for i in xrange(len(color_list)):
    barlist[i].set_color(color_list[i])

plt.ylabel('Number of Instances', size=80)
plt.xticks(ind, class_list, size=20,  rotation=90 )
ax.set_xlim([0, len(color_list)-1])
plt.yticks(np.arange(0, 3000, 1000), size=80)
plt.grid(axis = 'y', linestyle='--', linewidth = 10)


th1 = plt.text(15, 200, 'furniture', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(48, 200, 'mammal', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(75, 200, 'tool', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(100, 200, 'cloth', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(125, 200, 'electricity', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(148, 200, 'building', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(169, 200, 'office', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(189, 200, 'human body', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(205, 200, 'road transport', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(220, 200, 'food', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(234, 200, 'nature', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(248, 200, 'cold blooded', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(260, 200, 'other', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(270, 200, 'music', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(281, 200, 'fruit', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(290, 200, 'sport', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(298, 200, 'tree', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(305, 200, 'bird', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(313, 200, 'vegetable', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(320, 200, 'shape', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(327, 200, 'kitchen', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(334.5, 200, 'water transport', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(339.5, 200, 'sky transport', fontsize=80, rotation=90, rotation_mode='anchor')
th1 = plt.text(343, 200, 'insect', fontsize=80, rotation=90, rotation_mode='anchor')


plt.show()
fig.savefig("group_sort_by_sum.pdf", bbox_inches='tight')

# %%
groupp_ct = {}
for i in xrange(345):
    groupp = group_list[i]
    if not groupp in groupp_ct:
        groupp_ct[groupp] = values_list[i]
    else:
        groupp_ct[groupp] += values_list[i]

# %%
for i in  groupp_ct:
    groupp_ct[i] /=  598466.
groupp_ct
# Out:
# {'bird': 0.024024756627778355,
#  'building': 0.0639150762115141,
#  'cloth': 0.06482907968038285,
#  'cold blooded': 0.039295465406556096,
#  'electricity': 0.06447985349209479,
#  'food': 0.04039327213241855,
#  'fruit': 0.027958146327443832,
#  'furniture': 0.09933730571160267,
#  'human body': 0.0575671800904312,
#  'insect': 0.01151109670390632,
#  'kitchen': 0.01963854254042836,
#  'mammal': 0.08222689342418785,
#  'music': 0.027983210407942972,
#  'nature': 0.03931718760965535,
#  'office': 0.0511608011148503,
#  'other': 0.036045489635167245,
#  'road transportation': 0.04642870271661214,
#  'shape': 0.02038712307800276,
#  'sky transportation': 0.012136027777684948,
#  'sport': 0.02663476287708909,
#  'tool': 0.07326397823769437,
#  'tree': 0.025430016074430295,
#  'vegetable': 0.02312077879110927,
#  'water transportation': 0.018804744129156878}

# %%
sum_dict  = {sum(all_ct_dict[k]):k for k in all_ct_dict}


clipart_value = []
infograph_value = []
painting_value = []
quickdraw_value = []
real_value = []
sketch_value = []

for k in sorted_sum:
    
    clipart_value.append(clipart_ct_dict[sum_dict[k]])
    infograph_value.append(infograph_ct_dict[sum_dict[k]])
    painting_value.append(painting_ct_dict[sum_dict[k]])
    quickdraw_value.append(quickdraw_ct_dict[sum_dict[k]])
    real_value.append(real_ct_dict[sum_dict[k]])
    sketch_value.append(sketch_ct_dict[sum_dict[k]])
    
clipart_value = np.array(clipart_value)
infograph_value = np.array(infograph_value)
painting_value = np.array(painting_value)
quickdraw_value = np.array(quickdraw_value)
real_value = np.array(real_value)
sketch_value = np.array(sketch_value)

# %%
import numpy as np
import matplotlib.pyplot as plt


ind = np.arange(len(sorted_class))    # the x locations for the groups
width = 0.8      # the width of the bars: can also be len(x) sequence

fig, ax = plt.subplots(figsize=(100,15))
#plt.figure()


ax.bar(ind, clipart_value, width, color='purple',label='clipart', alpha=0.7,edgecolor='black',linewidth=0.1)
ax.bar(ind, infograph_value, width, color='green',label='infograph', alpha=0.7,edgecolor='black',linewidth=0.1, bottom=clipart_value)
ax.bar(ind, painting_value, width, color='yellow',label='painting', alpha=0.7,edgecolor='black',linewidth=0.1, bottom=clipart_value+infograph_value)
ax.bar(ind, quickdraw_value, width, color='b',label='quickdraw', alpha=0.7,edgecolor='black',linewidth=0.1, bottom=painting_value+clipart_value+infograph_value)
ax.bar(ind, real_value, width, color='pink', label='real',alpha=0.7,edgecolor='black',linewidth=0.1, bottom=quickdraw_value+painting_value+clipart_value+infograph_value)
ax.bar(ind, sketch_value, width, color='red',label='sketch', alpha=0.7,edgecolor='black',linewidth=0.1, bottom=real_value+quickdraw_value+painting_value+clipart_value+infograph_value)

plt.ylabel('Number of Instances', size=80)
plt.xticks(ind, sorted_class, size=20,  rotation=90 )
ax.set_xlim([0, len(sorted_sum)-1])
plt.yticks(np.arange(0, 3000, 1000), size=80)
plt.grid(axis = 'y', linestyle='--', linewidth = 10)
plt.legend(fontsize=46)
plt.show()
fig.savefig("colored_Annotated_instances2.pdf", bbox_inches='tight')
